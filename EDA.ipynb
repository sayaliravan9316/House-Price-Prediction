# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#import cleaned dataset
df = pd.read_csv('cleaned-home-data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60368 entries, 0 to 60367
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Location              60368 non-null  object
#  1   Carpet Area           60368 non-null  float64
#  2   Transaction           60368 non-null  object
#  3   Furnishing            60368 non-null  object
#  4   Bathroom              60368 non-null  float64
#  5   Balcony               60368 non-null  float64
#  6   Area(in sqft)         60368 non-null  float64
#  7   BHK                   60368 non-null  float64
#  8   FlatFloor             60368 non-null  float64
#  9   TotalFloors           60368 non-null  float64
#  10  ParkingNumbers        60368 non-null  int64
#  11  Parking Type          60368 non-null  object
#  12  SalePrice(in Crores)  60368 non-null  float64
#  13  state                 60368 non-null  object
# dtypes: float64(8), int64(1), object(5)
# ...

# %%
#df.describe()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['Area(in sqft)'], df['SalePrice(in Crores)'])
plt.xlabel('Area (sqft)')
plt.ylabel('Sale Price (Crores)')
plt.title('Area vs House Price')
plt.show()

# %%
 df['SalePrice(in Crores)'].describe()
# Out:
# count    60368.000000
# mean         1.017052
# std          3.126942
# min          0.010000
# 25%          0.410000
# 50%          0.648000
# 75%          1.050000
# max        510.040000
# Name: SalePrice(in Crores), dtype: float64

# %%
plt.figure(figsize=(8,5))

plt.boxplot(df['SalePrice(in Crores)'])

plt.ylabel('Sale Price (Crores)')
plt.title('Sale Price Box Plot')

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(df['Carpet Area'], df['SalePrice(in Crores)'])

plt.xlabel('Carpet Area')
plt.ylabel('Sale Price (Crores)')
plt.title('Carpet Area vs Sale Price')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

sns.boxplot(x='BHK', y='SalePrice(in Crores)', data=df)

plt.xlabel('BHK')
plt.ylabel('Sale Price (Crores)')
plt.title('BHK vs Sale Price')

plt.show()

# %%
df.columns
# Out:
# Index(['Location', 'Carpet Area', 'Transaction', 'Furnishing', 'Bathroom',
#        'Balcony', 'Area(in sqft)', 'BHK', 'FlatFloor', 'TotalFloors',
#        'ParkingNumbers', 'Parking Type', 'SalePrice(in Crores)', 'state'],
#       dtype='object')

# %%
plt.figure(figsize=(12,6))

sns.boxplot(x='Location', y='SalePrice(in Crores)', data=df)

plt.xlabel('Location')
plt.ylabel('Sale Price (Crores)')
plt.title('Location vs Sale Price')
plt.xticks(rotation=90)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x='Bathroom', y='SalePrice(in Crores)', data=df)

plt.xlabel('Bathroom')
plt.ylabel('Sale Price (Crores)')
plt.title('Bathroom vs Sale Price')

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.boxplot(x='FlatFloor', y='SalePrice(in Crores)', data=df)

plt.xlabel('Flat Floor')
plt.ylabel('Sale Price (Crores)')
plt.title('Flat Floor vs Sale Price')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,7))

sns.heatmap(
    df.select_dtypes(include='number').corr(),
    annot=True
)

plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x='Transaction', y='SalePrice(in Crores)', data=df)

plt.xlabel('Transaction')
plt.ylabel('Sale Price (Crores)')
plt.title('Transaction vs Sale Price')

plt.show()

# %%
(df == 0).sum()
# Out:
# Location                    0
# Carpet Area                 0
# Transaction                 0
# Furnishing                  0
# Bathroom                    0
# Balcony                 15791
# Area(in sqft)               0
# BHK                         0
# FlatFloor                3423
# TotalFloors                 0
# ParkingNumbers          34674
# Parking Type                0
# SalePrice(in Crores)        0
# state                       0
# dtype: int64

# %%
df['Transaction'].value_counts()
# Out:
# Transaction
# Resale          44597
# New Property    15662
# Unknown            57
# Other              50
# Rent/Lease          2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.countplot(x='Transaction', data=df)

plt.xlabel('Transaction Type')
plt.ylabel('Number of Properties')
plt.title('Transaction Type Distribution')

plt.show()

# %%
df['Furnishing'].value_counts()
# Out:
# Furnishing
# Semi-Furnished    26215
# Unfurnished       25273
# Furnished          8153
# Unknown             727
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.countplot(x='Furnishing', data=df)

plt.xlabel('Furnishing Type')
plt.ylabel('Number of Properties')
plt.title('Furnishing Type Distribution')

plt.show()

# %%
df['Parking Type'].value_counts()
# Out:
# Parking Type
# Not Available    34674
# Covered          22305
# Open              3389
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.countplot(x='Parking Type', data=df)

plt.xlabel('Parking Type')
plt.ylabel('Number of Properties')
plt.title('Parking Type Distribution')

plt.show()

# %%
df['BHK'].value_counts()
# Out:
# BHK
# 3.0     26148
# 2.0     23463
# 4.0      5469
# 1.0      4664
# 5.0       508
# 6.0        77
# 10.0       16
# 7.0        11
# 8.0         6
# 9.0         6
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    x='BHK',
    data=df,
    order=sorted(df['BHK'].dropna().unique())
)

plt.xlabel('BHK')
plt.ylabel('Number of Properties')
plt.title('BHK Distribution')

plt.show()

# %%
df['Bathroom'].value_counts().sort_index()
# Out:
# Bathroom
# 1.0      5514
# 2.0     31069
# 3.0     17841
# 4.0      4546
# 5.0      1187
# 6.0       164
# 7.0        23
# 8.0        10
# 9.0         5
# 10.0        9
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    x='Bathroom',
    data=df,
    order=sorted(df['Bathroom'].dropna().unique())
)

plt.xlabel('Number of Bathrooms')
plt.ylabel('Number of Properties')
plt.title('Bathroom Distribution')

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.boxplot(x='FlatFloor', y='SalePrice(in Crores)', data=df)

plt.xlabel('Flat Floor')
plt.ylabel('Sale Price (Crores)')
plt.title('Flat Floor vs Sale Price')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))

sns.boxplot(x='TotalFloors', y='SalePrice(in Crores)', data=df)

plt.xlabel('Total Floors')
plt.ylabel('Sale Price (Crores)')
plt.title('Total Floors vs Sale Price')
plt.xticks(rotation=90)
plt.show()
